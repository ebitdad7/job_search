# %%
import job_searches
from job_searches import find_jobs_from

# %%
desired_characs = ['titles','companies','links','date_listed']

# %%
find_jobs_from('Indeed','data analyst', 'omaha', desired_characs)
# Out:
# 15 new job postings retrieved from Indeed. Stored in results.xls.

# %%
import pandas as pd
file = r'results.xls'
results = pd.read_excel(file)
results
# Out:
#     Unnamed: 0                                             titles  \
# 0            0                          Sr. Business Analyst\nnew
# 1            1          Senior Business Intelligence Analyst\nnew
# 2            2  Senior Business Services Analyst - Data Manage...
# 3            3                      Business Systems Analyst\nnew
# 4            4                          Data Analyst Manager\nnew
# 5            5                    Sr. Data Analyst - Pricing\nnew
# 6            6                        Business Objects Admin\nnew
# 7            7             Business Intelligence Coordinator\nnew
# 8            8                               PROGRAM ANALYST\nnew
# 9            9                        Business Complaints Analyst
# 10          10                                   Business Analyst
# 11          11                         Technical Business Analyst
# 12          12  Data Analyst III (Business Analytics/ Tableau)...
# 13          13                     Trust & Safety Content Analyst
# 14          14                     Insurance Data Analyst I or II
#
#                          companies  \
# 0                           Fiserv
# 1             Creighton University
# 2                   Conagra Brands
# 3                   Conagra Brands
# 4                     Fiserv, Inc.
# 5                        Spreetail
# 6               CATCH Intelligence
# 7                    Right at Home
# 8   US Department of the Air Force
# 9                           PayPal
# 10                       Axos Bank
# 11          Titan School Solutions
# 12      Signature Performance, Inc
# 13                       Genesis10
# 14      National Indemnity Company
#
#                                                 links  date_listed
# 0   www.Indeed.com//pagead/clk?mo=r&ad=-6NYlbfkN0B...  Just posted
# 1   www.Indeed.com//rc/clk?jk=489448ee18af897a&fcc...        Today
# 2   www.Indeed.com//rc/clk?jk=46b179f88c570790&fcc...        Today
# 3   www.Indeed.com//rc/clk?jk=ef1547e3a1d9d023&fcc...        Today
# 4   www.Indeed.com//rc/clk?jk=4878890878e6426f&fcc...   3 days ago
# 5   www.Indeed.com//rc/clk?jk=d0b75d3e8d159e98&fcc...   5 days ago
# 6   www.Indeed.com//rc/clk?jk=c8d151cf3acf9e4f&fcc...   5 days ago
# 7   www.Indeed.com//rc/clk?jk=1b9ae33645c3e354&fcc...   7 days ago
# 8   www.Indeed.com//rc/clk?jk=408d83525dcc1e55&fcc...   7 days ago
# 9   www.Indeed.com//rc/clk?jk=38f63f0668cdc27f&fcc...  10 days ago
# 10  www.Indeed.com//rc/clk?jk=caecfc1977105ecc&fcc...  12 days ago
# 11  www.Indeed.com//rc/clk?jk=9c1e22714932d04d&fcc...  10 days ago
# 12  www.Indeed.com//pagead/clk?mo=r&ad=-6NYlbfkN0D...  19 days ago
# 13                      www.Indeed.com//cmp/Genesis10  15 days ago
# 14  www.Indeed.com//rc/clk?jk=ca60027b89bb6968&fcc...  17 days ago
